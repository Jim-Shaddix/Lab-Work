# %%
a = 10
b = 11
for i in range(10):
    print("i:", i)
c = 11
print("a:", a)
# Out:
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# a: 10

# %%
print("a,b:", a,b)
# Out:
# a,b: 10 11

# %% [markdown]
# # This is a heading???

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-5,5)
y = np.cos(x)
plt.plot(x, y, label="y")
plt.xlabel("x")
plt.ylabel("y")
plt.title("y vs. x")
plt.legend()
plt.show()

# %% [markdown]
# ## Title
# * that is right proper cool!
# 	- I am very surprised this works!!!

# %% [markdown]
# # This is a heading???
