# %% [markdown]
# ## Dope Life
# 1. this is awsome!!!
# 2. I can just use pycharm from now on!!!!
# 3. alot of the same shortcuts still work!!!

# %%
print("Finished")

for i in range(1,11):
    print("i:", i)
# Out:
# Finished
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# i: 10

# %% [markdown]
# ### Wonder
# * If links work??? [thing](google.com)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,6*np.pi)
y1 = np.cos(x)
y2 = np.sin(x)

plt.plot(x,y1)
plt.plot(x,y2)
plt.title("Dope Life")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
print("cool")
# Out:
# cool

# %%
import pandas as pd
df = pd.DataFrame({'x':x,'y':y1})

# %%
print(df.head(10))
# Out:
#           x         y
# 0  0.000000  1.000000
# 1  0.384685  0.926917
# 2  0.769370  0.718349
# 3  1.154054  0.404783
# 4  1.538739  0.032052
# 5  1.923424 -0.345365
# 6  2.308109 -0.672301
# 7  2.692794 -0.900969
# 8  3.077479 -0.997945
# 9  3.462163 -0.949056

# %%
nums = np.arange(1001)
# %time
nums = [x**2 for x in nums]
# Out:
# CPU times: user 6 µs, sys: 2 µs, total: 8 µs
# Wall time: 31 µs

# %%
nums = np.arange(1001,dtype="float64")
print("nums.dtpye:", nums.dtype)
print("nums.ndim:", nums.ndim)
a = 5
a
# Out:
# nums.dtpye: float64
# nums.ndim: 1
# 5

# %%
display(df.head(5))
# Out:
#           x         y
# 0  0.000000  1.000000
# 1  0.384685  0.926917
# 2  0.769370  0.718349
# 3  1.154054  0.404783
# 4  1.538739  0.032052
